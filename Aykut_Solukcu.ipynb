# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Aykut SOLUKCU
# <p> Math Teacher / Future Data Scientist

# %% [markdown]
# <i> I am interested in data science because as a math teacher i am familiar with statistics and data, and i also love to visualize data.

# %% [markdown]
# <h3> The Following Code will show the graph of linear equation

# %%
import matplotlib.pyplot as plt
import numpy as np
a=2
b=3
x=np.linspace(-3,3,100)
y=a*x+b
plt.plot(x,y, label=y)
plt.show()

# %% [markdown]
# | İndex | Area | Price |
# | --- | --- | --- |
# | 0 | 120 | 250.000 |
# | 1 | 130 | 270.000 |
# | 2 | 150 | 300.000 |

# %% [markdown]
# [My Page](https://www.ibm.com/)

# %% [markdown]
# * First - Birinci
# * Second - İkinci
# * Third - Üçüncü
